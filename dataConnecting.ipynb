# %%
import pandas as pd
import numpy as np

# %%
# krpc/dataLogging.ipynb krpc/vessel_data_533d19f0.csv krpc/vessel_data_bc520568.csv krpc/vessel_data_c2e8500b.csv
data1 = pd.read_csv('vessel_data_a405baf2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # krpc/dataLogging.ipynb krpc/vessel_data_533d19f0.csv krpc/vessel_data_bc520568.csv krpc/vessel_data_c2e8500b.csv
# ----> 2 data1 = pd.read_csv('vessel_data_a405baf2.csv')
#
# ...

# %%
#removing the first row from all the files, as it contains the column names
data3 = data1.drop([0])
data3
# Out:
#             Speed   G-Force  Altitude (Sea Level)  Altitude (Ground)  \
# 1        0.000091  0.994897             83.998494          11.591139
# 2        0.000105  0.994850             83.998496          11.591141
# 3        0.000106  0.994854             83.998498          11.591143
# 4        0.000094  0.994856             83.998500          11.591145
# 5        0.000096  0.994853             83.998503          11.591148
# ...           ...       ...                   ...                ...
# 1405  1643.249694  0.000000           1049.869337          -8.246549
# 1406  1643.249694  0.000000           1049.869337          -8.246549
# 1407  1643.249694  0.000000           1049.869337          -8.246549
# 1408  1643.249694  0.000000           1049.869337          -8.246549
# 1409  1643.249694  0.000000           1049.869337          -8.246549
#
#            Pressure          Mass  Thrust  atmospheric_density      Position1  \
# ...

# %%
tdata = pd.read_csv('training_Vessel_data.csv')

# %%
# merging all the data into one file
data = pd.concat([data1, tdata], ignore_index=True)
data
# Out:
#              Speed   G-Force  Altitude (Sea Level)  Altitude (Ground)  \
# 0         0.000068  0.994850             83.998489          11.591133
# 1         0.000091  0.994897             83.998494          11.591139
# 2         0.000105  0.994850             83.998496          11.591141
# 3         0.000106  0.994854             83.998498          11.591143
# 4         0.000094  0.994856             83.998500          11.591145
# ...            ...       ...                   ...                ...
# 13176  1806.581640  0.000000           4890.562874          -9.734814
# 13177  1806.581640  0.000000           4890.562874          -9.734814
# 13178  1806.581640  0.000000           4890.562874          -9.734814
# 13179  1806.581640  0.000000           4890.562874          -9.734814
# 13180  1806.581640  0.000000           4890.562874          -9.734814
#
#             Pressure          Mass  Thrust  atmospheric_density  \
# ...

# %%
# saving the data into a csv file
data.to_csv('training_Vessel_data.csv', index=False)
